# %%
# !git clone https://github.com/dave123981/commerce-recommendation-engine.git
# %cd commerce-recommendation-engine
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'commerce-recommendation-engine'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 117 (delta 54), reused 65 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (117/117), 40.36 KiB | 3.10 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# /content/commerce-recommendation-engine/commerce-recommendation-engine/commerce-recommendation-engine/commerce-recommendation-engine

# %%
# !pwd

# !ls
# Out:
# /content/commerce-recommendation-engine/commerce-recommendation-engine
# data  notebooks  README.md  requirements.txt  src

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: mlxtend>=0.23 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (0.23.4)
# Requirement already satisfied: tensorflow>=2.15 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: pytest>=7.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (8.4.2)
# Requirement already satisfied: matplotlib>=3.7 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: seaborn>=0.12 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.13.2)
# Requirement already satisfied: kaggle>=1.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 1)) (2026.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->-r requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (1.81.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.15->-r requirements.txt (line 6)) (0.5.4)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.4->-r requirements.txt (line 7)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.4->-r requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.4->-r requirements.txt (line 7)) (2.20.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 8)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 8)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 8)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 8)) (3.3.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6->-r requirements.txt (line 10)) (6.4.0)
# Requirement already satisfied: jupytext in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6->-r requirements.txt (line 10)) (1.19.4)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.20 in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6->-r requirements.txt (line 10)) (0.1.23)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6->-r requirements.txt (line 10)) (8.0.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6->-r requirements.txt (line 10)) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6->-r requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=2.15->-r requirements.txt (line 6)) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow>=2.15->-r requirements.txt (line 6)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow>=2.15->-r requirements.txt (line 6)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow>=2.15->-r requirements.txt (line 6)) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.15->-r requirements.txt (line 6)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.15->-r requirements.txt (line 6)) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.15->-r requirements.txt (line 6)) (2026.6.17)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow>=2.15->-r requirements.txt (line 6)) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow>=2.15->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow>=2.15->-r requirements.txt (line 6)) (3.1.8)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->kaggle>=1.6->-r requirements.txt (line 10)) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (4.2.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (0.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (5.10.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (6.0.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->kaggle>=1.6->-r requirements.txt (line 10)) (1.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=1.0->jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow>=2.15->-r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (2026.5.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle>=1.6->-r requirements.txt (line 10)) (4.10.0)

# %%
# !pip install -q kagglehub
import kagglehub
kagglehub.login()   # small browser popup, only needed once per session

# !python data/download_data.py          # kagglehub is now the default method
# !python data/build_interactions.py
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Downloading to /root/.cache/kagglehub/datasets/psparks/instacart-market-basket-analysis/1.archive...
# 100% 197M/197M [00:01<00:00, 162MB/s]
# Extracting files...
# kagglehub cached the dataset at /root/.cache/kagglehub/datasets/psparks/instacart-market-basket-analysis/versions/1
# Copied CSVs to /content/commerce-recommendation-engine/commerce-recommendation-engine/data/raw
# Built 32,664,602 interactions | 175,072 users | 42,529 items | 3,229,920 orders
# Saved to /content/commerce-recommendation-engine/commerce-recommendation-engine/data/interactions.csv
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
import pandas as pd

interactions = pd.read_csv("data/interactions.csv", parse_dates=["timestamp"])

print(interactions.shape)
print(interactions.nunique())
print("sparsity:", 1 - len(interactions) / (interactions.user_id.nunique() * interactions.item_id.nunique()))
print("orders per user:", interactions.groupby("user_id").order_id.nunique().describe())
print("purchases per item:", interactions.groupby("item_id").order_id.nunique().describe())
# Out:
# (32664602, 5)
# user_id       175072
# item_id        42529
# order_id     3229920
# timestamp        366
# quantity           1
# dtype: int64
# sparsity: 0.9956129204775982
# orders per user: count    175072.000000
# mean         18.449095
# std          17.151432
# min           2.000000
# 25%           7.000000
# 50%          12.000000
# 75%          23.000000
# max         100.000000
# Name: order_id, dtype: float64
# purchases per item: count     42529.000000
# mean        768.054786
# std        5226.329338
# min          10.000000
# 25%          29.000000
# 50%          87.000000
# 75%         336.000000
# max      476386.000000
# Name: order_id, dtype: float64

# %%
import data.build_interactions as bi
interactions = bi.build_interactions(min_orders_per_user=10, min_purchases_per_item=50)
interactions.to_csv("data/interactions.csv", index=False)

# %%
from src.metrics import time_based_split

train, test = time_based_split(interactions, test_frac=0.2)
train.to_csv("data/train.csv", index=False)
test.to_csv("data/test.csv", index=False)
print(len(train), len(test))
# Out:
# 22297249 5520463

# %%
from src.v1_popularity import PopularityRecommender
from src.metrics import evaluate_model

model = PopularityRecommender(half_life_days=30).fit(train)
metrics = evaluate_model(model, test, k=10)
print(metrics)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_10994/4280302573.py in <cell line: 0>()
# ----> 1 from src.v1_popularity import PopularityRecommender
#       2 from src.metrics import evaluate_model
#       3
#       4 model = PopularityRecommender(half_life_days=30).fit(train)
#       5 metrics = evaluate_model(model, test, k=10)
#
# ModuleNotFoundError: No module named 'src.v1_popularity'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pwd
# Out:
# /content/commerce-recommendation-engine/commerce-recommendation-engine/commerce-recommendation-engine/commerce-recommendation-engine
